# %%
import google.generativeai as genai

genai.configure(api_key='AIzaSyCVtUqd27aZEG328fpelgVSSIPmubrlcQ4')

text = """
Machine learning helps computers learn from data and improve performance
without explicit programming. It is widely used in recommendation systems
and fraud detection.
"""

model = genai.GenerativeModel("gemini-flash-lite-latest")

prompt = f"Create a short and clear summary of the following text:\n{text}"

response = model.generate_content(prompt)

print("Original Text:")
print(text)

print("\nSummarized Text:")
print(response.text)
# Out:
# Original Text:
#
# Machine learning helps computers learn from data and improve performance
# without explicit programming. It is widely used in recommendation systems
# and fraud detection.
#
#
# Summarized Text:
# Machine learning enables computers to learn from data and improve performance without explicit programming, commonly used in areas like recommendation systems and fraud detection.
